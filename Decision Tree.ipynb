# %% [markdown]
# # Decision Tree

# %% [markdown]
# ![image.png](attachment:27f9fb96-c703-4cc8-a852-c8e82d7b72c7.png)

# %% [markdown]
# * A Decision tree is a Flow based Machine learning aglo. Which is most likely works as if-else blocks. Thats is Highly interpretable.
# * Decision Tree often mimic the human level of thinking so its so simle to understand the data an make good assumptions.
# *

# %% [markdown]
# ![image.png](attachment:775ccc46-c1db-4215-abd0-a5de5bd099ac.png)

# %% [markdown]
#     1. As we already talked about it we have to find out the features where we need to start creating the blocks.
#     2. To find out which is the more important features we have to look for the heightest information-gain among all features

# %% [markdown]
# ## 1. Finding out Information gain

# %% [markdown]
#     1. Information gain for featurex1 = Parent Entropy - (Weighted average of entropy of child nodes)

# %% [markdown]
# ### 2. Parent Entropy

# %%
# Formula

# %% [markdown]
# ![image.png](attachment:fb216607-f190-4ac1-b542-c3df47a324d5.png)

# %% [markdown]
# # Ensamble Method:
#     1. Bagging
#     2. Boosting
#     3. Stacking
#     4.Voting

# %% [markdown]
# <!-- Diffrence between diffrent boosting xgboost, grident boosting, adaboosting -->
#
# Diffrent Bagging --> aggregating/ bootstarping /

# %% [markdown]
# ## Ensamble
#
# * The general principle of an ensemble method in Machine Learning to combine the predictions of several models. These are built with a given learning algorithm in order to improve robustness over a single model. Ensemble methods can be divided into two groups:
#
#     1. Bagging
#     2. Boosting
#
#
#
#
# ### Bagging
#
# * This is Parallel ensamble method.Where the final result determise by aggreagting result from small models,
#
#
# ## Random Forest
#
# * Learning trees are very popular base models for ensemble methods. Strong learners composed of multiple trees can be called “forests”. Trees that compose a forest can be chosen to be either shallow (few depths) or deep (lot of depths, if not fully grown). Shallow trees have less variance but higher bias and then will be better choice for sequential methods that we will described thereafter. Deep trees, on the other side, have low bias but high variance and, so, are relevant choices for bagging method that is mainly focused at reducing variance.

# %% [markdown]
# ## Used Ensamble methods
#
# 1. Random forest            -- Bagging
# 2. Adaptative boosting      -- Boosting
# 3. Gradient boosting        -- Boosting
# 4. eXtrem Gradient Boosting -- Boosting
# 5. Stacking model           -- Stacking
# 6. Multi-levels Stacking    -- Stacking

# %% [markdown]
# # Interview Question DT--RF--Boosting

# %% [markdown]
# #### Q. What is the intution Behind Decision Tree ?
# * This is not a plane based separator like logistic or svm, its more like a if-else block structured algorithm.
#
# #### Q. How to build a decision Tree ?
#
# #### Q. What is Entropy?
#
# #### Q. What is Information Gain ?
#
# #### Q. What is Gini Impurity ?
#
# #### Q. How to construct a DT ?
#
# #### Q. Entropy, Information Gain, Gini Index, Reducing Impurity? 2nd pdf ineuron
#
# #### Q. CART Algorithm (Classification and Regression trees ? 2nd pdf ineuron
#
# #### Q. How to control leaf height and Pruning ? 2nd pdf ineuron
#
# #### Q. How to handle a decision tree for numerical and categorical data? 2nd pdf ineuron
#
# #### Q. Importance if splitting numerical features ?
#
# #### Q. How to handle overfitting and underfitting ?
#
# #### Q. What is Train and run time complexity ?
#
# #### Q. How to implement regression using Decision Tree ?
#
# #### Q. How you find the root node ?
#
# #### Q. Is there any diffrence if all the features are numerical or all categorical ?
#
# #### Q. How to determine number of leaf node ?
#
# #### Q. What is KL Divergence ?
#
# #### Q. What is the adavantages of Gini impurity over entropy & when to use gini impurity and when entropy ?
#
# #### Q. Does Imbalanced data impact on DT ?
#
# #### Q. What about large number of features ?
#
# #### Q. What is adavantages of DT and some Dis-adavanatages?
#
# #### Q. What is Bias variance tradeoff of Decision Tree ?
#
# #### Q. What is Ensamble method ? AAIC -- 2nd pdf ineuron
#
# #### Q. What are the type of ensamble method there is ?
#
# #### Q. What is Bagging ?
#
# #### Q. What is Boosting ?
#
# #### Q. What is the Random Forest Algorithm? 2nd pdf ineuron
#
# #### Q. What are diffrent type of boosting techniques are out thr ?
#
# #### Q. What is the difference between Adptive boosting and Gridient boosting ?
#
# #### Q. What is Bias variance tradeoff of Bagging and boosting algos ?
#
# #### Q. What is Extremely Randomized trees ?
#
# #### Q. What is feature importance and how to calculate ?
#
# #### Q. Regularization for DT, Ensamble method ?
#
# #### Q. What are stacking models ?
#
# #### Q. What are residual, loss function and gridients ?
#
# #### Q. What is reguralization y srinkage ?
#
# #### Q. Explain XGBoost ?
#
# #### Q. Explain AdaBoost ?
#
# #### Q. How to implement Stacking models ?
#
# #### Q. What are Cascading classifiers ?
