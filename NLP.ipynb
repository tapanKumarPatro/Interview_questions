# %% [markdown]
# # NLP

# %% [markdown]
# # Natural Language Processing

# %% [markdown]
# #### What is Natural Language Processing ?
#
# #### What are different techniques for text encoding ?
#
# #### What is TF-IDF ?
#
# #### What is count Vectorizer ?
#
# #### When to use count vectorizer or tf-idf vectorizer ?
#
# #### What are the text preprocessing steps ?
#
# #### What is Bag of words ?
#
# #### Why we remove stop words ?
#
# #### What sequential model to use and when ?
#
# #### What is purning ?
#
# #### How to decide what seqential models to use.?
#
# #### What is Syntactic Analysis? (Parsing -> Word Segementation -> Morphological Segementation -> Stemming -> Lemmatization )
#      1. Parsing: It helps in deciding the structure of a sentence or text in a document. It helps analyze the words in the text based on the grammar of the language.
#      2. Word segmentation: The segmentation of words segregates the text into small significant units.
#      3. Morphological segmentation: The purpose of morphological segmentation is to break words into their base form.
#      4. Stemming: It is the process of removing the suffix from a word to obtain its root word.
#      5. Lemmatization: It helps combine words using suffixes, without altering the meaning of the word.
#
# #### What is semantic Analysis ? (NER -> Word Sense disambiguation -> Natural Laguage generation)
#
# #### What is NLTK ?
#
# #### How to tokenize a sentence using the nltk package ?
#
# #### Explain how we can do parsing ?
#
# #### Explain steamming with the help of an Example ? PorterStemmer
#
# #### Explain Lemmatization with the help of an example ?
#
# #### What is Parts-of-speech Tagging ?
#
# #### Explain Named Entity Recognition by implementing it ?
#
# #### How to check word similarity using the spacy package ?
#
# #### List the components of Natural Language Processing ?
#
# #### Define the terminology in NLP ?
#      1. Weights and Vector
#          * Use of TF-IDF for information retrieval
#          * Length (TF-IDF and docs)
#          * Google Word Vectors
#          * Word Vectors
#
#      2. Structure of the Text
#          * POS tagging
#          * Head of the sentence
#          * Named Entity Recognition (NER)
#
#      3. Sentiment Analysis
#          * Knowledge of the charcteristics of sentiment
#          * Knowledge about entities and the common dictonary availabe for sentiment analysis
#
#      4. Classification of Text
#          * Supervised learning algorithm
#          * Traning set
#          * Validation set
#          * Test set
#          * Features of the text
#          * LDA
#
#      5. Machine Reading
#          * Removal of possible entities
#          * Joining with other entities
#          * DBpedia
#
#
# #### What is Latent Semantic Indexing(LSI) ?
#
# #### What are regular expressions ?
#
# #### What is regular grammar ?
#
# #### Explain Dependency parsing in NLP ?
#
# #### What is difference between NLP and NLU ?
#
# #### What is differnce between NLP and CI ?
#
# #### What is Pragmatic Analysis ?
#
# #### What is Pragmatic Ambiguity ?
#
# #### What are unigrams, bigrams, trigrams, and n-grams in NLP ?
#
# #### What are the steps involved in solving an NLP problem ?
#
# #### What is Parsing in the context of NLP ?
#
# #### What is Feature Extraction in NLP ?
#
# #### What is precision and recall ?
#
# #### What is F1 score ?
#
# #### Have you done Topic modeling ?
#
# ####
